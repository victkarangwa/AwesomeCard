# %% [markdown]
# <a href="https://colab.research.google.com/github/victkarangwa/AwesomeCard/blob/master/aiml03_l7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 1
#
# Follow the instructions in the comments to complete the missing code in the below cell.

# %%
# Your Q1 Solution
import pyarrow as pa
import pyarrow.compute as pc

data = {
    'name': ['Emmanuel', 'Mohamed', 'Emmanuella', 'Aline'],
    'age': [25, 30, 26, 25],
    'score': [85, 92.5, 88, 96]
}

# Create a pyarrow table using the data above


# Now write code to print the age column and then another line of code to convert it to numpy and print again

# Get table schema and print it


# Try at least three slice strategies and print the result


# Write code to filter all elements with age greater than 24


# Calculate the maximum, minimum, std, average, and median for the columns with numerical values


# Now write code to sort the table with ascending order, with age being the first priority, print the results


# Finally, write a function that takes in any table in this form and returns the names of people who scored better than average
def avg_score(tbl):
  names = ....
  return names
